# %%
import cv2
from darkflow.net.build import TFNet
import numpy as np
import time

options = {
    'model': 'cfg/yolov2-tiny.cfg',
    'load': 'bin/yolov2-tiny_3000.weights',
    'threshold': 0.1,
    'gpu':0.7,
}
tfnet = TFNet(options)

colors = [tuple(255 * np.random.rand(3)) for _ in range(10)]

capture = cv2.VideoCapture(0)
capture.set(cv2.CAP_PROP_FRAME_WIDTH, 1920)
capture.set(cv2.CAP_PROP_FRAME_HEIGHT, 1080)

while True:
    stime = time.time()
    ret, frame = capture.read()
    if ret:
        results = tfnet.return_predict(frame)
        for color, result in zip(colors, results):
            tl = (result['topleft']['x'], result['topleft']['y'])
            br = (result['bottomright']['x'], result['bottomright']['y'])
            label = result['label']
            confidence = result['confidence']
            text = '{}: {:.0f}%'.format(label, confidence * 100)
            frame = cv2.rectangle(frame, tl, br, color, 5)
            frame = cv2.putText(
                frame, text, tl, cv2.FONT_HERSHEY_COMPLEX, 1, (0, 0, 0), 2)
        cv2.imshow('frame', frame)
        print('FPS {:.1f}'.format(1 / (time.time() - stime)))
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

capture.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\Tanay\Desktop\Helmet Detection\darkflow-master\darkflow\dark\darknet.py:54: UserWarning: ./cfg/yolov2-tiny_3000.cfg not found, use cfg/yolov2-tiny.cfg instead
#   cfg_path, FLAGS.model))
# Parsing cfg/yolov2-tiny.cfg
# Loading bin/yolov2-tiny_3000.weights ...
# Successfully identified 44148320 bytes
# Finished in 0.024934053421020508s
#
# Building net ...
# Source | Train? | Layer description                | Output size
# -------+--------+----------------------------------+---------------
#        |        | input                            | (?, 416, 416, 3)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 416, 416, 16)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 208, 208, 16)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 208, 208, 32)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 104, 104, 32)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 104, 104, 64)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 52, 52, 64)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 52, 52, 128)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 26, 26, 128)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 26, 26, 256)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 13, 13, 256)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 512)
#  Load  |  Yep!  | maxp 2x2p0_1                     | (?, 13, 13, 512)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 1024)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 13, 13, 512)
#  Load  |  Yep!  | conv 1x1p0_1    linear           | (?, 13, 13, 35)
# -------+--------+----------------------------------+---------------
# GPU mode with 0.7 usage
# Finished in 4.920639991760254s
#
# FPS 0.9
# FPS 5.4
# FPS 5.4
# FPS 5.8
# FPS 5.4
# FPS 5.7
# FPS 5.6
# FPS 5.9
# FPS 5.7
# FPS 5.8
# FPS 5.6
# FPS 5.7
# FPS 5.6
# FPS 5.5
# FPS 5.6
# FPS 5.6
# FPS 5.5
# FPS 5.2
# FPS 5.1
# FPS 5.4
# FPS 5.5
# FPS 5.2
# FPS 5.2
# FPS 5.1
# FPS 5.4
# FPS 5.3
# FPS 5.4
# FPS 5.2
# FPS 5.4
# FPS 5.6
# FPS 5.5
# FPS 5.4
# FPS 5.4
# FPS 5.7
# FPS 5.4
# FPS 5.4
# FPS 5.2
# FPS 5.4
# FPS 5.5
# FPS 5.4
# FPS 5.6
# FPS 5.1
# FPS 5.6
# FPS 5.3
# FPS 5.2
# FPS 5.4
# FPS 5.4
# FPS 5.2
# FPS 5.6
# FPS 5.4
# FPS 5.3
# FPS 5.2
# FPS 5.4
# FPS 5.2
# FPS 5.1
# FPS 5.3
# FPS 5.3
# FPS 5.1
# FPS 5.4
# FPS 5.3
# FPS 5.1
# FPS 5.5
# FPS 5.0
# FPS 5.3
# FPS 5.3
# FPS 5.2
# FPS 5.3
# FPS 5.2
# FPS 5.2
# FPS 5.1
# FPS 5.2
# FPS 5.1
# FPS 5.1
# FPS 5.0
# FPS 5.3
# FPS 5.1
# FPS 5.2
# FPS 5.3
# FPS 5.6
# FPS 5.4
# FPS 5.9
# FPS 5.6
# FPS 5.8
# FPS 5.5
# FPS 5.7
# FPS 5.5
# FPS 5.4
# FPS 5.6
# FPS 5.5
# FPS 5.5
# FPS 5.7
# FPS 5.7
# FPS 5.6
# FPS 5.7
# FPS 5.6
# FPS 5.6
# FPS 5.6
# FPS 5.4
# FPS 5.7
# FPS 5.5
# FPS 5.7
# FPS 5.6
# FPS 5.6
# FPS 5.6
# FPS 5.5
# FPS 5.7
# FPS 5.7
# FPS 5.7
# FPS 5.6
# FPS 5.6
# FPS 5.4
# FPS 5.6
# FPS 5.7
# FPS 5.5
# FPS 5.7
# FPS 5.4
# FPS 5.8
# FPS 5.4
# FPS 5.7
# FPS 5.8
# FPS 6.0
# FPS 5.2
# FPS 5.9
# FPS 5.7
# FPS 5.5
# FPS 5.7
# FPS 5.4
# FPS 5.6
# FPS 5.7
# FPS 5.5
# FPS 5.6

# %%
import tensorflow
